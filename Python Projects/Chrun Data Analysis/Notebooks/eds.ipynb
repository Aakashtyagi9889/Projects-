# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import streamlit as st

# %%
df = pd.read_csv(r"E:\Croma\Projects\Python Projects\Chrun Data Analysis\Datasets\Churn_Modelling.csv")

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.head(2)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1          1               1
# 1       1  83807.86              1          0               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  str
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  str
#  5   Gender           10000 non-null  str
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), str(3)
# memory usage: 1.2 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
newdf = df.copy()

# %%
gender = st.selectbox("Select Gender" , newdf['Gender'].unique())
# Out:
# 2026-07-24 02:12:03.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-24 02:12:03.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-24 02:12:03.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-24 02:12:03.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-24 02:12:03.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-24 02:12:03.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
newdf=newdf[newdf['Gender']==gender]

# %%
newdf.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
newdf.groupby('Geography')['Balance'].sum().reset_index()
# Out:
#   Geography       Balance
# 0    France  1.363896e+08
# 1   Germany  1.421411e+08
# 2     Spain  6.518982e+07

# %%
newdf.rename(columns={'Geography' : 'Country'})
# Out:
#       RowNumber  CustomerId      Surname  CreditScore  Country  Gender  Age  \
# 0             1    15634602     Hargrave          619   France  Female   42
# 1             2    15647311         Hill          608    Spain  Female   41
# 2             3    15619304         Onio          502   France  Female   42
# 3             4    15701354         Boni          699   France  Female   39
# 4             5    15737888     Mitchell          850    Spain  Female   43
# ...         ...         ...          ...          ...      ...     ...  ...
# 9982       9983    15768163      Griffin          655  Germany  Female   46
# 9991       9992    15769959  Ajuluchukwu          597   France  Female   53
# 9994       9995    15719294         Wood          800   France  Female   29
# 9997       9998    15584532          Liu          709   France  Female   36
# 9999      10000    15628319       Walker          792   France  Female   28
#
# ...

# %%
newdf['Exited'] = newdf['Exited'].replace({
  0:'Stay connected',
  1:'Exited'
})

# %%
newdf.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary          Exited
# 0        101348.88          Exited
# 1        112542.58  Stay connected
# 2        113931.57          Exited
# ...

# %%
newdf.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4543 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        4543 non-null   int64
#  1   CustomerId       4543 non-null   int64
#  2   Surname          4543 non-null   str
#  3   CreditScore      4543 non-null   int64
#  4   Geography        4543 non-null   str
#  5   Gender           4543 non-null   str
#  6   Age              4543 non-null   int64
#  7   Tenure           4543 non-null   int64
#  8   Balance          4543 non-null   float64
#  9   NumOfProducts    4543 non-null   int64
#  10  HasCrCard        4543 non-null   int64
#  11  IsActiveMember   4543 non-null   int64
#  12  EstimatedSalary  4543 non-null   float64
#  13  Exited           4543 non-null   int64
# dtypes: float64(2), int64(9), str(3)
# memory usage: 616.0 KB
